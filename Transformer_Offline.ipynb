# %% [markdown]
# <a href="https://colab.research.google.com/github/Bassendiaye/mes_notebooks/blob/main/Transformer_Offline.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install torch torchvision albumentations matplotlib sklearn pillow timm
# Out:
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (2.8.0+cu126)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.12/dist-packages (0.23.0+cu126)
# Requirement already satisfied: albumentations in /usr/local/lib/python3.12/dist-packages (2.0.8)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (3.10.0)
# Collecting sklearn
#   Downloading sklearn-0.0.post12.tar.gz (2.6 kB)
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Preparing metadata (setup.py) ... error
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from collections import Counter
from PIL import Image
import albumentations as A
from albumentations.pytorch import ToTensorV2
import torch
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
import torch.nn as nn
import torch.optim as optim
import random
import cv2
from collections import defaultdict
from uuid import uuid4
from tqdm import tqdm

# %%
# 1. Analyse et visualisation de la distribution des classes
def plot_class_distribution(data_dir):
  # Dictionnaire pour stocker le nombre d'images par classe
  repartition = {}

  # Extensions d'images
  extensions = ('.png', '.jpg', '.jpeg', '.bmp', '.gif')

  # Comptage des images
  for nom_classe in os.listdir(data_dir):
      chemin_classe = os.path.join(data_dir, nom_classe)
      if os.path.isdir(chemin_classe):
          nb_images = len([f for f in os.listdir(chemin_classe) if f.lower().endswith(extensions)])
          repartition[nom_classe] = nb_images

  # Calcul des pourcentages
  total_images = sum(repartition.values())
  repartition_pourcentages = {classe: (nb / total_images) * 100 for classe, nb in repartition.items()}

  # -------- GRAPHE À BARRES --------
  plt.figure(figsize=(10, 6))
  bars = plt.bar(repartition.keys(), repartition.values(), color='skyblue')
  plt.xlabel("Classes")
  plt.ylabel("Nombre d'images")
  plt.title("Répartition des images par classe")
  plt.xticks(rotation=45)

  # Affichage des pourcentages au-dessus des barres
  for bar in bars:
      hauteur = bar.get_height()
      classe = bar.get_x() + bar.get_width() / 2
      pourcentage = (hauteur / total_images) * 100
      plt.text(classe, hauteur + 1, f"{pourcentage:.1f}%", ha='center', va='bottom', fontsize=10, color='black')

  plt.tight_layout()
  plt.show()
  return repartition

# %%
def prepare_data_with_oversampling(data_dir, test_size=0.1, random_state=42, max_samples_per_class=4000):

    IMG_HEIGHT = 46
    IMG_WIDTH = 322

    class_names = sorted([d for d in os.listdir(data_dir) if os.path.isdir(os.path.join(data_dir, d))])

    file_paths, labels = [], []
    for class_idx, class_name in enumerate(class_names):
        class_dir = os.path.join(data_dir, class_name)
        class_files = [
            os.path.join(class_dir, f)
            for f in os.listdir(class_dir)
            if f.lower().endswith(('.png', '.jpg', '.jpeg'))
        ]
        file_paths.extend(class_files)
        labels.extend([class_idx] * len(class_files))

    train_files, val_files, train_labels, val_labels = train_test_split(
        file_paths, labels, test_size=test_size, stratify=labels, random_state=random_state
    )

    def get_individual_transforms():
        return [
            A.HorizontalFlip(p=0.5),
            A.VerticalFlip(p=0.5),
            A.ElasticTransform(alpha=1, sigma=50, alpha_affine=50, p=1),
            A.GridDistortion(num_steps=5, distort_limit=0.3, p=1),
            A.RandomBrightnessContrast(brightness_limit=0.2, contrast_limit=0.2, p=1),
            A.RGBShift(r_shift_limit=20, g_shift_limit=20, b_shift_limit=20, p=1),
            A.HueSaturationValue(hue_shift_limit=15, sat_shift_limit=20, val_shift_limit=15, p=1),
            A.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.1, p=1),
            A.Defocus(radius=(3, 5), p=1),
            A.MotionBlur(blur_limit=(3, 5), p=1),
            A.GaussianBlur(blur_limit=(3, 5), p=1)
        ]

    def oversample_with_separate_transforms(files, labels):
        label_to_files = defaultdict(list)
        for f, l in zip(files, labels):
            label_to_files[l].append(f)

        transforms = get_individual_transforms()
        base_transform = A.Compose([
            A.Resize(height=IMG_HEIGHT, width=IMG_WIDTH),
            A.Normalize(mean=(0.5, 0.5, 0.5), std=(0.5, 0.5, 0.5)),
            ToTensorV2()
        ])

        AUG_DIR = os.path.join(os.path.dirname(data_dir), "/content/drive/MyDrive/Dossier_de_Basse/split_4000_images_balanced")
        os.makedirs(AUG_DIR, exist_ok=True)

        oversampled_files, oversampled_labels = [], []

        for label, file_list in tqdm(label_to_files.items(), desc="Balancing classes"):
            n = len(file_list)

            if n == max_samples_per_class:
                oversampled_files.extend(file_list)
                oversampled_labels.extend([label] * n)

            elif n > max_samples_per_class:
                sampled = random.sample(file_list, max_samples_per_class)
                oversampled_files.extend(sampled)
                oversampled_labels.extend([label] * max_samples_per_class)

            else:  # Sur-échantillonnage
                oversampled_files.extend(file_list)
                oversampled_labels.extend([label] * n)
                needed = max_samples_per_class - n
                idx = 0
                while needed > 0:
                    img_path = file_list[idx % n]
                    image = cv2.imread(img_path)
                    if image is None:
                        idx += 1
                        continue
                    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

                    for t in transforms:
                        if needed <= 0:
                            break
                        composed = A.Compose([t, base_transform])
                        augmented = composed(image=image)
                        aug_tensor = augmented["image"]

                        aug_np = aug_tensor.permute(1, 2, 0).cpu().numpy()
                        aug_np = np.clip((aug_np * 0.5 + 0.5) * 255, 0, 255).astype("uint8")
                        aug_bgr = cv2.cvtColor(aug_np, cv2.COLOR_RGB2BGR)

                        new_path = os.path.join(AUG_DIR, f"{uuid4().hex}.jpg")
                        if cv2.imwrite(new_path, aug_bgr):
                            oversampled_files.append(new_path)
                            oversampled_labels.append(label)
                            needed -= 1
                    idx += 1

        return oversampled_files, oversampled_labels

    train_files, train_labels = oversample_with_separate_transforms(train_files, train_labels)

    return train_files, val_files, train_labels, val_labels, class_names

# %%
# 3. Dataset personnalisé avec Albumentations
class CustomDataset(Dataset):
    def __init__(self, file_paths, labels, transform=None):
        self.file_paths = file_paths
        self.labels = labels
        self.transform = transform

    def __len__(self):
        return len(self.file_paths)

    def __getitem__(self, idx):
        image = Image.open(self.file_paths[idx]).convert('RGB')
        image = np.array(image)
        label = self.labels[idx]

        if self.transform:
            augmented = self.transform(image=image)
            image = augmented['image']

        return image, label

# %%
def get_val_transform():
    return A.Compose([
        A.Resize(height=IMG_HEIGHT, width=IMG_WIDTH),
        A.Normalize(mean=(0.5, 0.5, 0.5), std=(0.5, 0.5, 0.5)),
        ToTensorV2()
    ])

# %%
# 5. Entraînement du modèle
def train_model(model, train_loader, val_loader, criterion, optimizer, num_epochs=25, device='cuda'):
    model = model.to(device)
    best_acc = 0.0

    for epoch in range(num_epochs):
        model.train()
        running_loss = 0.0
        running_corrects = 0

        for inputs, labels in train_loader:
            inputs = inputs.to(device)
            labels = labels.to(device)

            optimizer.zero_grad()

            outputs = model(inputs)
            loss = criterion(outputs, labels)

            loss.backward()
            optimizer.step()

            _, preds = torch.max(outputs, 1)
            running_loss += loss.item() * inputs.size(0)
            running_corrects += torch.sum(preds == labels.data)

        epoch_loss = running_loss / len(train_loader.dataset)
        epoch_acc = running_corrects.double() / len(train_loader.dataset)

        val_loss, val_acc = evaluate(model, val_loader, criterion, device)

        print(f'Epoch {epoch+1}/{num_epochs}')
        print(f'Train Loss: {epoch_loss:.4f}, Acc: {epoch_acc:.4f}')
        print(f'Val Loss: {val_loss:.4f}, Acc: {val_acc:.4f}')

        if val_acc > best_acc:
            best_acc = val_acc
            torch.save(model.state_dict(), '/content/drive/MyDrive/Dossier_de_Basse/split_4000_best_model.pth')
            print(f" Meilleur modèle sauvegardé ! Avec best_val_acc = {best_acc: .2f}% ")

    return model

# %%
def evaluate(model, loader, criterion, device):
    model.eval()
    running_loss = 0.0
    running_corrects = 0

    with torch.no_grad():
        for inputs, labels in loader:
            inputs = inputs.to(device)
            labels = labels.to(device)

            outputs = model(inputs)
            loss = criterion(outputs, labels)

            _, preds = torch.max(outputs, 1)
            running_loss += loss.item() * inputs.size(0)
            running_corrects += torch.sum(preds == labels.data)

    loss = running_loss / len(loader.dataset)
    acc = running_corrects.double() / len(loader.dataset)

    return loss, acc

# %%
from tqdm import tqdm
def predict_image(image_path, model, class_names, device='cuda' if torch.cuda.is_available() else 'cpu'):
    # Transformations cohérentes avec l'entraînement
    transform = A.Compose([
        A.Resize(height=46, width=322),
        A.Normalize(mean=(0.5, 0.5, 0.5), std=(0.5, 0.5, 0.5)),
        ToTensorV2()
    ])

    # Lecture de l'image
    image = cv2.imread(image_path)
    if image is None:
        raise ValueError(f"Image non trouvée : {image_path}")
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

    # Appliquer la transformation
    augmented = transform(image=image)
    tensor_image = augmented['image'].unsqueeze(0).to(device)  # Ajouter la dimension batch

    # Prédiction
    model.eval()
    with torch.no_grad():
        outputs = model(tensor_image)
        _, predicted_idx = torch.max(outputs, 1)
        predicted_class = class_names[predicted_idx.item()]
        probabilities = torch.softmax(outputs, dim=1).cpu().numpy()[0]

    return predicted_class, predicted_idx.item(), probabilities

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

def get_test_transform():
    return A.Compose([
        A.Resize(height=46, width=322),
        A.Normalize(mean=(0.5, 0.5, 0.5), std=(0.5, 0.5, 0.5)),
        ToTensorV2()
    ])

def generate_confusion_matrix(model, test_files, test_labels, class_names, device='cuda' if torch.cuda.is_available() else 'cpu'):
    model.to(device)
    model.eval()

    y_true = []
    y_pred = []

    transform = get_test_transform()

    for img_path, label in tqdm(zip(test_files, test_labels), total=len(test_files), desc="Évaluation"):
        image = cv2.imread(img_path)
        if image is None:
            continue
        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
        augmented = transform(image=image)
        tensor_image = augmented['image'].unsqueeze(0).to(device)

        with torch.no_grad():
            output = model(tensor_image)
            predicted = torch.argmax(output, dim=1).item()

        y_true.append(label)
        y_pred.append(predicted)

    cm = confusion_matrix(y_true, y_pred)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=class_names)
    disp.plot(cmap=plt.cm.Blues, xticks_rotation=45)
    plt.title("Matrice de confusion")
    plt.tight_layout()
    plt.show()

# %%
def get_test_transform():
    return A.Compose([
        A.Resize(height=46, width=322),
        A.Normalize(mean=(0.5, 0.5, 0.5), std=(0.5, 0.5, 0.5)),
        ToTensorV2()
    ])

def generate_confusion_matrix(model, test_files, test_labels, class_names, device='cuda' if torch.cuda.is_available() else 'cpu'):
    model.to(device)
    model.eval()

    y_true = []
    y_pred = []

    transform = get_test_transform()

    for img_path, label in tqdm(zip(test_files, test_labels), total=len(test_files), desc="Évaluation"):
        image = cv2.imread(img_path)
        if image is None:
            continue
        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
        augmented = transform(image=image)
        tensor_image = augmented['image'].unsqueeze(0).to(device)

        with torch.no_grad():
            output = model(tensor_image)
            predicted = torch.argmax(output, dim=1).item()

        y_true.append(label)
        y_pred.append(predicted)

    cm = confusion_matrix(y_true, y_pred)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=class_names)
    disp.plot(cmap=plt.cm.Blues, xticks_rotation=45)
    plt.title("Matrice de confusion")
    plt.tight_layout()
    plt.show()

# %%
#***********************************************************************************************
# 1. Configuration
DATA_DIR = "/content/drive/MyDrive/Dossier_de_Basse/Data_paper_TrainVal_Test/train_Val"
BATCH_SIZE = 32
NUM_EPOCHS = 100

IMG_WIDTH = 224    # Largeur des images après redimensionnement
IMG_HEIGHT = 224     # Hauteur des images après redimensionnement
patch_size = 16     # Taille des patches

# Calcul du nombre de patches horizontaux et verticaux
num_patches_w = IMG_WIDTH // patch_size
num_patches_h = IMG_HEIGHT // patch_size
# Taux d'apprentissage (learning rate)
lr = 1e-4
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
# 2. Analyse des données
print("Analyse de la distribution des classes...")
class_counts = plot_class_distribution(DATA_DIR)
# Out:
# Analyse de la distribution des classes...

# %%
print("DATA_DIR =", DATA_DIR)
print("Sous-dossiers dans DATA_DIR :", os.listdir(DATA_DIR))
for d in os.listdir(DATA_DIR):
    # Check if the entry is a directory before listing its contents
    full_path = os.path.join(DATA_DIR, d)
    if os.path.isdir(full_path):
        print(f"{d} → {len(os.listdir(full_path))} fichiers")
    else:
        print(f"{d} → Not a directory")
# Out:
# DATA_DIR = /content/drive/MyDrive/Dossier_de_Basse/Data_paper_TrainVal_Test/train_Val
# Sous-dossiers dans DATA_DIR : ['NC', 'FSC', 'FS', 'FC', 'AFSC', 'AFS', 'AF', 'AFC']
# NC → 41 fichiers
# FSC → 16 fichiers
# FS → 70 fichiers
# FC → 14 fichiers
# AFSC → 828 fichiers
# AFS → 1287 fichiers
# AF → 12874 fichiers
# AFC → 297 fichiers

# %%
# 3. Préparation des données avec oversampling
print("\nPréparation des données avec oversampling...")
train_files, val_files, train_labels, val_labels, class_names = prepare_data_with_oversampling(DATA_DIR)
len(train_files), len(val_files)
# Out:
# Préparation des données avec oversampling...
# /tmp/ipython-input-3007851663.py:27: UserWarning: Argument(s) 'alpha_affine' are not valid for transform ElasticTransform
#   A.ElasticTransform(alpha=1, sigma=50, alpha_affine=50, p=1),
# Balancing classes: 100%|██████████| 8/8 [13:03<00:00, 97.89s/it]
# (32000, 1543)

# %%
# Afficher les distributions des labels (listes d'entiers)
def plot_label_distribution(labels, title):
    """Plots the distribution of labels in a list."""
    label_counts = Counter(labels)
    # Sort by label index for consistent plotting
    sorted_labels = sorted(label_counts.keys())
    sorted_counts = [label_counts[label] for label in sorted_labels]

    plt.figure(figsize=(12, 6))
    plt.bar([str(label) for label in sorted_labels], sorted_counts) # Convert labels to string for x-axis
    plt.title(title)
    plt.xlabel('Class Index')
    plt.ylabel('Number of samples')
    plt.xticks(rotation=45)
    plt.show()

print("Distribution des labels d'entraînement après oversampling...")
plot_label_distribution(train_labels, 'Distribution des labels d\'entraînement (après oversampling)')
# Out:
# Distribution des labels d'entraînement après oversampling...

# %%
print("\nDistribution des labels de validation...")
plot_label_distribution(val_labels, 'Distribution des labels de test')
# Out:
# Distribution des labels de validation...

# %%
# 4. Création des datasets et dataloaders
print("\nCréation des datasets et dataloaders...")
train_dataset = CustomDataset(train_files, train_labels, transform=get_val_transform())
val_dataset = CustomDataset(val_files, val_labels, transform=get_val_transform())
# Out:
# Création des datasets et dataloaders...

# %%
train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE, shuffle=False)

# %%
import timm
# 5. Initialisation du modèle pré-entraîné deit_small
num_classes = len(class_names)
model = timm.create_model("deit_small_patch16_224", pretrained=True, num_classes=num_classes).to(device)
# Out:
# model.safetensors:   0%|          | 0.00/88.2M [00:00<?, ?B/s]

# %%
# 6. Configuration de l'entraînement
criterion = nn.CrossEntropyLoss()
optimizer = optim.AdamW(model.parameters(), lr=1e-4, betas=(0.9, 0.999), weight_decay=0.01)

# %%
# 7. Entraînement
print("\nDébut de l'entraînement...")
trained_model = train_model(
    model=model,
    train_loader=train_loader,
    val_loader=val_loader,
    criterion=criterion,
    optimizer=optimizer,
    num_epochs=NUM_EPOCHS,
    device=device
)

print("Entraînement terminé !")
# Out:
# Début de l'entraînement...
# Epoch 1/100
# Train Loss: 0.1364, Acc: 0.9560
# Val Loss: 0.1752, Acc: 0.9540
#  Meilleur modèle sauvegardé ! Avec best_val_acc =  0.95%
# Epoch 2/100
# Train Loss: 0.0997, Acc: 0.9682
# Val Loss: 0.2836, Acc: 0.9145
# Epoch 3/100
# Train Loss: 0.0736, Acc: 0.9767
# Val Loss: 0.2621, Acc: 0.9248
# Epoch 4/100
# Train Loss: 0.0685, Acc: 0.9780
# Val Loss: 0.2253, Acc: 0.9371
# Epoch 5/100
# Train Loss: 0.0555, Acc: 0.9823
# Val Loss: 0.2181, Acc: 0.9488
# Epoch 6/100
# Train Loss: 0.0482, Acc: 0.9848
# Val Loss: 0.2681, Acc: 0.9287
# Epoch 7/100
# Train Loss: 0.0472, Acc: 0.9853
# Val Loss: 0.2999, Acc: 0.9125
# Epoch 8/100
# Train Loss: 0.0357, Acc: 0.9892
# Val Loss: 0.2034, Acc: 0.9559
#  Meilleur modèle sauvegardé ! Avec best_val_acc =  0.96%
# Epoch 9/100
# Train Loss: 0.0420, Acc: 0.9861
# Val Loss: 0.2511, Acc: 0.9404
# Epoch 10/100
# Train Loss: 0.0365, Acc: 0.9883
# Val Loss: 0.3253, Acc: 0.9125
# Epoch 11/100
# Train Loss: 0.0267, Acc: 0.9917
# Val Loss: 0.3603, Acc: 0.8976
# Epoch 12/100
# Train Loss: 0.0344, Acc: 0.9888
# Val Loss: 0.2410, Acc: 0.9436
# Epoch 13/100
# Train Loss: 0.0254, Acc: 0.9924
# Val Loss: 0.2674, Acc: 0.9332
# Epoch 14/100
# Train Loss: 0.0259, Acc: 0.9922
# Val Loss: 0.2471, Acc: 0.9404
# Epoch 15/100
# Train Loss: 0.0230, Acc: 0.9927
# Val Loss: 0.2695, Acc: 0.9378
# Epoch 16/100
# Train Loss: 0.0242, Acc: 0.9925
# Val Loss: 0.2453, Acc: 0.9443
# Epoch 17/100
# Train Loss: 0.0191, Acc: 0.9942
# Val Loss: 0.2402, Acc: 0.9501
# Epoch 18/100
# Train Loss: 0.0227, Acc: 0.9928
# Val Loss: 0.2652, Acc: 0.9404
# Epoch 19/100
# Train Loss: 0.0196, Acc: 0.9938
# Val Loss: 0.2535, Acc: 0.9482
# Epoch 20/100
# Train Loss: 0.0174, Acc: 0.9948
# Val Loss: 0.2338, Acc: 0.9592
#  Meilleur modèle sauvegardé ! Avec best_val_acc =  0.96%
# Epoch 21/100
# Train Loss: 0.0158, Acc: 0.9956
# Val Loss: 0.2780, Acc: 0.9397
# Epoch 22/100
# Train Loss: 0.0195, Acc: 0.9938
# Val Loss: 0.2079, Acc: 0.9598
#  Meilleur modèle sauvegardé ! Avec best_val_acc =  0.96%
# Epoch 23/100
# Train Loss: 0.0190, Acc: 0.9943
# Val Loss: 0.2116, Acc: 0.9520
# Epoch 24/100
# Train Loss: 0.0177, Acc: 0.9956
# Val Loss: 0.2356, Acc: 0.9436
# Epoch 25/100
# Train Loss: 0.0143, Acc: 0.9955
# Val Loss: 0.2347, Acc: 0.9520
# Epoch 26/100
# Train Loss: 0.0197, Acc: 0.9940
# Val Loss: 0.2633, Acc: 0.9475
# Epoch 27/100
# Train Loss: 0.0155, Acc: 0.9953
# Val Loss: 0.2536, Acc: 0.9410
# Epoch 28/100
# Train Loss: 0.0144, Acc: 0.9960
# Val Loss: 0.2045, Acc: 0.9533
# Epoch 29/100
# Train Loss: 0.0153, Acc: 0.9955
# Val Loss: 0.2258, Acc: 0.9572
# Epoch 30/100
# Train Loss: 0.0089, Acc: 0.9972
# Val Loss: 0.2465, Acc: 0.9514
# Epoch 31/100
# Train Loss: 0.0179, Acc: 0.9949
# Val Loss: 0.2194, Acc: 0.9598
# Epoch 32/100
# Train Loss: 0.0145, Acc: 0.9961
# Val Loss: 0.2212, Acc: 0.9553
# Epoch 33/100
# Train Loss: 0.0107, Acc: 0.9968
# Val Loss: 0.2162, Acc: 0.9553
# Epoch 34/100
# Train Loss: 0.0136, Acc: 0.9964
# Val Loss: 0.2280, Acc: 0.9494
# Epoch 35/100
# Train Loss: 0.0138, Acc: 0.9959
# Val Loss: 0.2416, Acc: 0.9566
# Epoch 36/100
# Train Loss: 0.0131, Acc: 0.9961
# Val Loss: 0.2754, Acc: 0.9417
# Epoch 37/100
# Train Loss: 0.0120, Acc: 0.9970
# Val Loss: 0.2370, Acc: 0.9546
# Epoch 38/100
# Train Loss: 0.0101, Acc: 0.9971
# Val Loss: 0.2334, Acc: 0.9533
# Epoch 39/100
# Train Loss: 0.0096, Acc: 0.9973
# Val Loss: 0.3370, Acc: 0.9268
# Epoch 40/100
# Train Loss: 0.0163, Acc: 0.9949
# Val Loss: 0.2508, Acc: 0.9462
# Epoch 41/100
# Train Loss: 0.0092, Acc: 0.9973
# Val Loss: 0.2419, Acc: 0.9475
# Epoch 42/100
# Train Loss: 0.0097, Acc: 0.9972
# Val Loss: 0.1971, Acc: 0.9592
# Epoch 43/100
# Train Loss: 0.0133, Acc: 0.9964
# Val Loss: 0.2501, Acc: 0.9456
# Epoch 44/100
# Train Loss: 0.0104, Acc: 0.9968
# Val Loss: 0.2297, Acc: 0.9404
# Epoch 45/100
# Train Loss: 0.0114, Acc: 0.9965
# Val Loss: 0.2312, Acc: 0.9482
# Epoch 46/100
# Train Loss: 0.0098, Acc: 0.9970
# Val Loss: 0.2946, Acc: 0.9358
# Epoch 47/100
# Train Loss: 0.0105, Acc: 0.9967
# Val Loss: 0.2423, Acc: 0.9572
# Epoch 48/100
# Train Loss: 0.0075, Acc: 0.9977
# Val Loss: 0.2903, Acc: 0.9352
# Epoch 49/100
# Train Loss: 0.0087, Acc: 0.9975
# Val Loss: 0.2505, Acc: 0.9559
# Epoch 50/100
# Train Loss: 0.0093, Acc: 0.9973
# Val Loss: 0.3283, Acc: 0.9248
# Epoch 51/100
# Train Loss: 0.0141, Acc: 0.9958
# Val Loss: 0.2381, Acc: 0.9482
# Epoch 52/100
# Train Loss: 0.0082, Acc: 0.9978
# Val Loss: 0.2448, Acc: 0.9520
# Epoch 53/100
# Train Loss: 0.0083, Acc: 0.9979
# Val Loss: 0.2168, Acc: 0.9631
#  Meilleur modèle sauvegardé ! Avec best_val_acc =  0.96%
# Epoch 54/100
# Train Loss: 0.0093, Acc: 0.9973
# Val Loss: 0.2169, Acc: 0.9540
# Epoch 55/100
# Train Loss: 0.0091, Acc: 0.9974
# Val Loss: 0.2405, Acc: 0.9585
# Epoch 56/100
# Train Loss: 0.0088, Acc: 0.9975
# Val Loss: 0.2142, Acc: 0.9605
# Epoch 57/100
# Train Loss: 0.0050, Acc: 0.9988
# Val Loss: 0.3335, Acc: 0.9365
# Epoch 58/100
# Train Loss: 0.0143, Acc: 0.9961
# Val Loss: 0.2770, Acc: 0.9501
# Epoch 59/100
# Train Loss: 0.0085, Acc: 0.9974
# Val Loss: 0.2867, Acc: 0.9436
# Epoch 60/100
# Train Loss: 0.0069, Acc: 0.9981
# Val Loss: 0.3269, Acc: 0.9397
# Epoch 61/100
# Train Loss: 0.0035, Acc: 0.9992
# Val Loss: 0.2369, Acc: 0.9559
# Epoch 62/100
# Train Loss: 0.0167, Acc: 0.9953
# Val Loss: 0.2578, Acc: 0.9449
# Epoch 63/100
# Train Loss: 0.0064, Acc: 0.9982
# Val Loss: 0.2575, Acc: 0.9501
# Epoch 64/100
# Train Loss: 0.0074, Acc: 0.9977
# Val Loss: 0.2601, Acc: 0.9501
# Epoch 65/100
# Train Loss: 0.0030, Acc: 0.9992
# Val Loss: 0.2730, Acc: 0.9533
# Epoch 66/100
# Train Loss: 0.0127, Acc: 0.9965
# Val Loss: 0.2530, Acc: 0.9605
# Epoch 67/100
# Train Loss: 0.0052, Acc: 0.9986
# Val Loss: 0.2611, Acc: 0.9559
# Epoch 68/100
# Train Loss: 0.0097, Acc: 0.9972
# Val Loss: 0.2503, Acc: 0.9540
# Epoch 69/100
# Train Loss: 0.0060, Acc: 0.9984
# Val Loss: 0.2496, Acc: 0.9546
# Epoch 70/100
# Train Loss: 0.0087, Acc: 0.9974
# Val Loss: 0.2488, Acc: 0.9546
# Epoch 71/100
# Train Loss: 0.0070, Acc: 0.9980
# Val Loss: 0.2641, Acc: 0.9449
# Epoch 72/100
# Train Loss: 0.0081, Acc: 0.9976
# Val Loss: 0.2546, Acc: 0.9527
# Epoch 73/100
# Train Loss: 0.0074, Acc: 0.9980
# Val Loss: 0.2575, Acc: 0.9456
# Epoch 74/100
# Train Loss: 0.0080, Acc: 0.9975
# Val Loss: 0.2087, Acc: 0.9605
# Epoch 75/100
# Train Loss: 0.0063, Acc: 0.9982
# Val Loss: 0.2484, Acc: 0.9605
# Epoch 76/100
# Train Loss: 0.0107, Acc: 0.9972
# Val Loss: 0.2433, Acc: 0.9482
# Epoch 77/100
# Train Loss: 0.0056, Acc: 0.9984
# Val Loss: 0.2421, Acc: 0.9579
# Epoch 78/100
# Train Loss: 0.0081, Acc: 0.9978
# Val Loss: 0.2342, Acc: 0.9566
# Epoch 79/100
# Train Loss: 0.0074, Acc: 0.9981
# Val Loss: 0.2106, Acc: 0.9618
# Epoch 80/100
# Train Loss: 0.0064, Acc: 0.9984
# Val Loss: 0.3495, Acc: 0.9287
# Epoch 81/100
# Train Loss: 0.0068, Acc: 0.9981
# Val Loss: 0.2505, Acc: 0.9449
# Epoch 82/100
# Train Loss: 0.0093, Acc: 0.9971
# Val Loss: 0.2760, Acc: 0.9449
# Epoch 83/100
# Train Loss: 0.0027, Acc: 0.9993
# Val Loss: 0.2706, Acc: 0.9507
# Epoch 84/100
# Train Loss: 0.0003, Acc: 0.9999
# Val Loss: 0.2696, Acc: 0.9624
# Epoch 85/100
# Train Loss: 0.0136, Acc: 0.9959
# Val Loss: 0.2426, Acc: 0.9507
# Epoch 86/100
# Train Loss: 0.0068, Acc: 0.9982
# Val Loss: 0.2703, Acc: 0.9462
# Epoch 87/100
# Train Loss: 0.0079, Acc: 0.9979
# Val Loss: 0.2303, Acc: 0.9566
# Epoch 88/100
# Train Loss: 0.0075, Acc: 0.9979
# Val Loss: 0.3432, Acc: 0.9177
# Epoch 89/100
# Train Loss: 0.0049, Acc: 0.9987
# Val Loss: 0.3292, Acc: 0.9384
# Epoch 90/100
# Train Loss: 0.0054, Acc: 0.9984
# Val Loss: 0.2493, Acc: 0.9566
# Epoch 91/100
# Train Loss: 0.0054, Acc: 0.9985
# Val Loss: 0.2292, Acc: 0.9566
# Epoch 92/100
# Train Loss: 0.0080, Acc: 0.9978
# Val Loss: 0.2546, Acc: 0.9572
# Epoch 93/100
# Train Loss: 0.0035, Acc: 0.9989
# Val Loss: 0.2504, Acc: 0.9611
# Epoch 94/100
# Train Loss: 0.0102, Acc: 0.9973
# Val Loss: 0.2192, Acc: 0.9546
# Epoch 95/100
# Train Loss: 0.0057, Acc: 0.9986
# Val Loss: 0.2485, Acc: 0.9566
# Epoch 96/100
# Train Loss: 0.0050, Acc: 0.9986
# Val Loss: 0.2345, Acc: 0.9566
# Epoch 97/100
# Train Loss: 0.0052, Acc: 0.9987
# Val Loss: 0.2704, Acc: 0.9443
# Epoch 98/100
# Train Loss: 0.0072, Acc: 0.9979
# Val Loss: 0.2802, Acc: 0.9527
# Epoch 99/100
# Train Loss: 0.0039, Acc: 0.9988
# Val Loss: 0.2446, Acc: 0.9559
# Epoch 100/100
# Train Loss: 0.0051, Acc: 0.9987
# Val Loss: 0.2417, Acc: 0.9592
# Entraînement terminé !

# %%
# Define TEST_DATA_DIR here to ensure it's always available
TEST_DATA_DIR = "/content/drive/MyDrive/Dossier_de_Basse/Data_paper_TrainVal_Test/test"
print(f"TEST_DATA_DIR defined as: {TEST_DATA_DIR}")

print("Collecting test image file paths and labels...")

test_files = []
test_labels = []

# Ensure class_names is available from previous steps. If not, try to generate it.
# Assuming class_names is already defined from the training phase and consistent.
if 'class_names' not in globals() or not class_names:
    print("Class names not found or empty. Attempting to generate from TEST_DATA_DIR...")
    if not os.path.exists(TEST_DATA_DIR):
        print(f"Error: TEST_DATA_DIR '{TEST_DATA_DIR}' does not exist. Please verify the path and ensure it's accessible.")
    else:
        try:
            class_names = sorted([d for d in os.listdir(TEST_DATA_DIR) if os.path.isdir(os.path.join(TEST_DATA_DIR, d))])
            if not class_names:
                print(f"Warning: No class subdirectories found in '{TEST_DATA_DIR}' to infer class names.")
            else:
                print(f"Generated class_names from TEST_DATA_DIR: {class_names}")
        except FileNotFoundError:
            print(f"Error: Could not access TEST_DATA_DIR '{TEST_DATA_DIR}'. Check permissions or path accuracy.")
else:
    print(f"Using existing class_names: {class_names}")


if not class_names or not os.path.exists(TEST_DATA_DIR):
    print("Cannot proceed with test data preparation: class names are not defined or TEST_DATA_DIR is inaccessible.")
else:
    for class_idx, class_name in enumerate(class_names):
        class_dir = os.path.join(TEST_DATA_DIR, class_name);
        if os.path.isdir(class_dir):
            files_in_class = [
                os.path.join(class_dir, f)
                for f in os.listdir(class_dir)
                if f.lower().endswith(('.png', '.jpg', '.jpeg', '.bmp', '.gif'))
            ]
            test_files.extend(files_in_class)
            test_labels.extend([class_idx] * len(files_in_class))
        else:
            print(f"Warning: Class directory '{class_dir}' not found within TEST_DATA_DIR. Skipping class '{class_name}'.")

    print(f"Found {len(test_files)} test images.")
    print(f"First 5 test files: {test_files[:5]}")
    print(f"First 5 test labels: {test_labels[:5]}")

    # 1. Création du dataset et dataloader de test
    print("\nCréation du dataset et dataloader de test...")
    # Make sure IMG_HEIGHT and IMG_WIDTH are defined in a prior cell, or define them here
    # For consistency, use the same transform as validation, which should be 'get_val_transform()'
    test_dataset = CustomDataset(test_files, test_labels, transform=get_val_transform())
    test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE, shuffle=False)
    print(f"Test dataset size: {len(test_dataset)}")

    # 2. Évaluation du modèle sur le set de test
    print("\nÉvaluation du modèle sur le set de test...")
    # Assuming 'trained_model' and 'criterion' are available from the training phase
    test_loss, test_acc = evaluate(trained_model, test_loader, criterion, device)
    print(f'Test Loss: {test_loss:.4f}, Test Acc: {test_acc:.4f}')

    # 3. Génération de la matrice de confusion
    #print("\nGénération de la matrice de confusion...")
    #generate_confusion_matrix(trained_model, test_files, test_labels, class_names, device)
    print("Partie test terminée !")
# Out:
# TEST_DATA_DIR defined as: /content/drive/MyDrive/Dossier_de_Basse/Data_paper_TrainVal_Test/test
# Collecting test image file paths and labels...
# Using existing class_names: ['AF', 'AFC', 'AFS', 'AFSC', 'FC', 'FS', 'FSC', 'NC']
# Found 1715 test images.
# First 5 test files: ['/content/drive/MyDrive/Dossier_de_Basse/Data_paper_TrainVal_Test/test/AF/Gel_IEF2020ID 051.jpg', '/content/drive/MyDrive/Dossier_de_Basse/Data_paper_TrainVal_Test/test/AF/Gel_IEF2020ID 045.jpg', '/content/drive/MyDrive/Dossier_de_Basse/Data_paper_TrainVal_Test/test/AF/Gel_IEF202056.jpg', '/content/drive/MyDrive/Dossier_de_Basse/Data_paper_TrainVal_Test/test/AF/Gel _EF2020513.jpg', '/content/drive/MyDrive/Dossier_de_Basse/Data_paper_TrainVal_Test/test/AF/Gel _EF2020507.jpg']
# First 5 test labels: [0, 0, 0, 0, 0]
#
# Création du dataset et dataloader de test...
# Test dataset size: 1715
#
# Évaluation du modèle sur le set de test...
# Test Loss: 0.3655, Test Acc: 0.9405
# Partie test terminée !
