# %% [markdown]
# <a href="https://colab.research.google.com/github/Bassendiaye/mes_notebooks/blob/main/Bassendiaye/mes_notebooks/Finetuning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install torch torchvision albumentations matplotlib sklearn pillow timm
# Out:
# Requirement already satisfied: torch in /usr/local/lib/python3.11/dist-packages (2.6.0+cu124)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.11/dist-packages (0.21.0+cu124)
# Requirement already satisfied: albumentations in /usr/local/lib/python3.11/dist-packages (2.0.8)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (3.10.0)
# Collecting sklearn
#   Downloading sklearn-0.0.post12.tar.gz (2.6 kB)
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Preparing metadata (setup.py) ... error
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from collections import Counter
from PIL import Image
import albumentations as A
from albumentations.pytorch import ToTensorV2
import torch
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
import torch.nn as nn
import torch.optim as optim
import random
import cv2
from collections import defaultdict
from uuid import uuid4
from tqdm import tqdm

# %%
# 1. Analyse et visualisation de la distribution des classes
def plot_class_distribution(data_dir):
  # Dictionnaire pour stocker le nombre d'images par classe
  repartition = {}

  # Extensions d'images
  extensions = ('.png', '.jpg', '.jpeg', '.bmp', '.gif')

  # Comptage des images
  for nom_classe in os.listdir(data_dir):
      chemin_classe = os.path.join(data_dir, nom_classe)
      if os.path.isdir(chemin_classe):
          nb_images = len([f for f in os.listdir(chemin_classe) if f.lower().endswith(extensions)])
          repartition[nom_classe] = nb_images

  # Calcul des pourcentages
  total_images = sum(repartition.values())
  repartition_pourcentages = {classe: (nb / total_images) * 100 for classe, nb in repartition.items()}

  # -------- GRAPHE À BARRES --------
  plt.figure(figsize=(10, 6))
  bars = plt.bar(repartition.keys(), repartition.values(), color='skyblue')
  plt.xlabel("Classes")
  plt.ylabel("Nombre d'images")
  plt.title("Répartition des images par classe")
  plt.xticks(rotation=45)

  # Affichage des pourcentages au-dessus des barres
  for bar in bars:
      hauteur = bar.get_height()
      classe = bar.get_x() + bar.get_width() / 2
      pourcentage = (hauteur / total_images) * 100
      plt.text(classe, hauteur + 1, f"{pourcentage:.1f}%", ha='center', va='bottom', fontsize=10, color='black')

  plt.tight_layout()
  plt.show()
  return repartition

# %%
def prepare_data_with_oversampling(data_dir, test_size=0.2, random_state=42, max_samples_per_class=2000):

    IMG_HEIGHT = 46
    IMG_WIDTH = 322

    class_names = sorted([d for d in os.listdir(data_dir) if os.path.isdir(os.path.join(data_dir, d))])

    file_paths, labels = [], []
    for class_idx, class_name in enumerate(class_names):
        class_dir = os.path.join(data_dir, class_name)
        class_files = [
            os.path.join(class_dir, f)
            for f in os.listdir(class_dir)
            if f.lower().endswith(('.png', '.jpg', '.jpeg'))
        ]
        file_paths.extend(class_files)
        labels.extend([class_idx] * len(class_files))

    train_files, test_files, train_labels, test_labels = train_test_split(
        file_paths, labels, test_size=test_size, stratify=labels, random_state=random_state
    )

    def get_individual_transforms():
        return [
            A.HorizontalFlip(p=1),
            A.VerticalFlip(p=1),
            A.ElasticTransform(alpha=1, sigma=50, alpha_affine=50, p=1),
            A.GridDistortion(num_steps=5, distort_limit=0.3, p=1),
            A.RandomBrightnessContrast(brightness_limit=0.2, contrast_limit=0.2, p=1),
            A.RGBShift(r_shift_limit=20, g_shift_limit=20, b_shift_limit=20, p=1),
            A.HueSaturationValue(hue_shift_limit=15, sat_shift_limit=20, val_shift_limit=15, p=1),
            A.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.1, p=1),
            A.Defocus(radius=(3, 5), p=1),
            A.MotionBlur(blur_limit=(3, 5), p=1),
            A.GaussianBlur(blur_limit=(3, 5), p=1)
        ]

    def oversample_with_separate_transforms(files, labels):
        label_to_files = defaultdict(list)
        for f, l in zip(files, labels):
            label_to_files[l].append(f)

        transforms = get_individual_transforms()
        base_transform = A.Compose([
            A.Resize(height=IMG_HEIGHT, width=IMG_WIDTH),
            A.Normalize(mean=(0.5, 0.5, 0.5), std=(0.5, 0.5, 0.5)),
            ToTensorV2()
        ])

        AUG_DIR = os.path.join(os.path.dirname(data_dir), "images_balanced")
        os.makedirs(AUG_DIR, exist_ok=True)

        oversampled_files, oversampled_labels = [], []

        for label, file_list in tqdm(label_to_files.items(), desc="Balancing classes"):
            n = len(file_list)

            if n == max_samples_per_class:
                oversampled_files.extend(file_list)
                oversampled_labels.extend([label] * n)

            elif n > max_samples_per_class:
                sampled = random.sample(file_list, max_samples_per_class)
                oversampled_files.extend(sampled)
                oversampled_labels.extend([label] * max_samples_per_class)

            else:  # Sur-échantillonnage
                oversampled_files.extend(file_list)
                oversampled_labels.extend([label] * n)
                needed = max_samples_per_class - n
                idx = 0
                while needed > 0:
                    img_path = file_list[idx % n]
                    image = cv2.imread(img_path)
                    if image is None:
                        idx += 1
                        continue
                    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

                    for t in transforms:
                        if needed <= 0:
                            break
                        composed = A.Compose([t, base_transform])
                        augmented = composed(image=image)
                        aug_tensor = augmented["image"]

                        aug_np = aug_tensor.permute(1, 2, 0).cpu().numpy()
                        aug_np = np.clip((aug_np * 0.5 + 0.5) * 255, 0, 255).astype("uint8")
                        aug_bgr = cv2.cvtColor(aug_np, cv2.COLOR_RGB2BGR)

                        new_path = os.path.join(AUG_DIR, f"{uuid4().hex}.jpg")
                        if cv2.imwrite(new_path, aug_bgr):
                            oversampled_files.append(new_path)
                            oversampled_labels.append(label)
                            needed -= 1
                    idx += 1

        return oversampled_files, oversampled_labels

    train_files, train_labels = oversample_with_separate_transforms(train_files, train_labels)

    return train_files, test_files, train_labels, test_labels, class_names

# %%
# 3. Dataset personnalisé avec Albumentations
class CustomDataset(Dataset):
    def __init__(self, file_paths, labels, transform=None):
        self.file_paths = file_paths
        self.labels = labels
        self.transform = transform

    def __len__(self):
        return len(self.file_paths)

    def __getitem__(self, idx):
        image = Image.open(self.file_paths[idx]).convert('RGB')
        image = np.array(image)
        label = self.labels[idx]

        if self.transform:
            augmented = self.transform(image=image)
            image = augmented['image']

        return image, label

# %%
def get_val_transform():
    return A.Compose([
        A.Resize(height=IMG_HEIGHT, width=IMG_WIDTH),
        A.Normalize(mean=(0.5, 0.5, 0.5), std=(0.5, 0.5, 0.5)),
        ToTensorV2()
    ])

# %%
# 5. Entraînement du modèle
def train_model(model, train_loader, val_loader, criterion, optimizer, num_epochs=25, device='cuda'):
    model = model.to(device)
    best_acc = 0.0

    for epoch in range(num_epochs):
        model.train()
        running_loss = 0.0
        running_corrects = 0

        for inputs, labels in train_loader:
            inputs = inputs.to(device)
            labels = labels.to(device)

            optimizer.zero_grad()

            outputs = model(inputs)
            loss = criterion(outputs, labels)

            loss.backward()
            optimizer.step()

            _, preds = torch.max(outputs, 1)
            running_loss += loss.item() * inputs.size(0)
            running_corrects += torch.sum(preds == labels.data)

        epoch_loss = running_loss / len(train_loader.dataset)
        epoch_acc = running_corrects.double() / len(train_loader.dataset)

        val_loss, val_acc = evaluate(model, val_loader, criterion, device)

        print(f'Epoch {epoch+1}/{num_epochs}')
        print(f'Train Loss: {epoch_loss:.4f}, Acc: {epoch_acc:.4f}')
        print(f'Val Loss: {val_loss:.4f}, Acc: {val_acc:.4f}')

        if val_acc > best_acc:
            best_acc = val_acc
            torch.save(model.state_dict(), 'best_model.pth')

    return model

# %%
def evaluate(model, loader, criterion, device):
    model.eval()
    running_loss = 0.0
    running_corrects = 0

    with torch.no_grad():
        for inputs, labels in loader:
            inputs = inputs.to(device)
            labels = labels.to(device)

            outputs = model(inputs)
            loss = criterion(outputs, labels)

            _, preds = torch.max(outputs, 1)
            running_loss += loss.item() * inputs.size(0)
            running_corrects += torch.sum(preds == labels.data)

    loss = running_loss / len(loader.dataset)
    acc = running_corrects.double() / len(loader.dataset)

    return loss, acc

# %%
from tqdm import tqdm
def predict_image(image_path, model, class_names, device='cuda' if torch.cuda.is_available() else 'cpu'):
    # Transformations cohérentes avec l'entraînement
    transform = A.Compose([
        A.Resize(height=46, width=322),
        A.Normalize(mean=(0.5, 0.5, 0.5), std=(0.5, 0.5, 0.5)),
        ToTensorV2()
    ])

    # Lecture de l'image
    image = cv2.imread(image_path)
    if image is None:
        raise ValueError(f"Image non trouvée : {image_path}")
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

    # Appliquer la transformation
    augmented = transform(image=image)
    tensor_image = augmented['image'].unsqueeze(0).to(device)  # Ajouter la dimension batch

    # Prédiction
    model.eval()
    with torch.no_grad():
        outputs = model(tensor_image)
        _, predicted_idx = torch.max(outputs, 1)
        predicted_class = class_names[predicted_idx.item()]
        probabilities = torch.softmax(outputs, dim=1).cpu().numpy()[0]

    return predicted_class, predicted_idx.item(), probabilities

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

def get_test_transform():
    return A.Compose([
        A.Resize(height=46, width=322),
        A.Normalize(mean=(0.5, 0.5, 0.5), std=(0.5, 0.5, 0.5)),
        ToTensorV2()
    ])

def generate_confusion_matrix(model, test_files, test_labels, class_names, device='cuda' if torch.cuda.is_available() else 'cpu'):
    model.to(device)
    model.eval()

    y_true = []
    y_pred = []

    transform = get_test_transform()

    for img_path, label in tqdm(zip(test_files, test_labels), total=len(test_files), desc="Évaluation"):
        image = cv2.imread(img_path)
        if image is None:
            continue
        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
        augmented = transform(image=image)
        tensor_image = augmented['image'].unsqueeze(0).to(device)

        with torch.no_grad():
            output = model(tensor_image)
            predicted = torch.argmax(output, dim=1).item()

        y_true.append(label)
        y_pred.append(predicted)

    cm = confusion_matrix(y_true, y_pred)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=class_names)
    disp.plot(cmap=plt.cm.Blues, xticks_rotation=45)
    plt.title("Matrice de confusion")
    plt.tight_layout()
    plt.show()

# %%
def get_test_transform():
    return A.Compose([
        A.Resize(height=46, width=322),
        A.Normalize(mean=(0.5, 0.5, 0.5), std=(0.5, 0.5, 0.5)),
        ToTensorV2()
    ])

def generate_confusion_matrix(model, test_files, test_labels, class_names, device='cuda' if torch.cuda.is_available() else 'cpu'):
    model.to(device)
    model.eval()

    y_true = []
    y_pred = []

    transform = get_test_transform()

    for img_path, label in tqdm(zip(test_files, test_labels), total=len(test_files), desc="Évaluation"):
        image = cv2.imread(img_path)
        if image is None:
            continue
        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
        augmented = transform(image=image)
        tensor_image = augmented['image'].unsqueeze(0).to(device)

        with torch.no_grad():
            output = model(tensor_image)
            predicted = torch.argmax(output, dim=1).item()

        y_true.append(label)
        y_pred.append(predicted)

    cm = confusion_matrix(y_true, y_pred)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=class_names)
    disp.plot(cmap=plt.cm.Blues, xticks_rotation=45)
    plt.title("Matrice de confusion")
    plt.tight_layout()
    plt.show()

# %%
#***********************************************************************************************
# 1. Configuration
DATA_DIR = "/content/drive/MyDrive/Dossier_de_Basse/Data_paper"
BATCH_SIZE = 32
NUM_EPOCHS = 100

IMG_WIDTH = 224    # Largeur des images après redimensionnement
IMG_HEIGHT = 224     # Hauteur des images après redimensionnement
patch_size = 16     # Taille des patches

# Calcul du nombre de patches horizontaux et verticaux
num_patches_w = IMG_WIDTH // patch_size
num_patches_h = IMG_HEIGHT // patch_size
# Taux d'apprentissage (learning rate)
lr = 1e-4
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
# 2. Analyse des données
print("Analyse de la distribution des classes...")
class_counts = plot_class_distribution(DATA_DIR)
# Out:
# Analyse de la distribution des classes...

# %%
print("DATA_DIR =", DATA_DIR)
print("Sous-dossiers dans DATA_DIR :", os.listdir(DATA_DIR))
for d in os.listdir(DATA_DIR):
    # Check if the entry is a directory before listing its contents
    full_path = os.path.join(DATA_DIR, d)
    if os.path.isdir(full_path):
        print(f"{d} → {len(os.listdir(full_path))} fichiers")
    else:
        print(f"{d} → Not a directory")
# Out:
# DATA_DIR = /content/drive/MyDrive/Dossier_de_Basse/Data_paper
# Sous-dossiers dans DATA_DIR : ['FC', 'AF', 'AFSC', 'AFS', 'NC', 'FS', 'AFC', 'FSC']
# FC → 16 fichiers
# AF → 14295 fichiers
# AFSC → 920 fichiers
# AFS → 1430 fichiers
# NC → 46 fichiers
# FS → 78 fichiers
# AFC → 330 fichiers
# FSC → 18 fichiers

# %%
# 3. Préparation des données avec oversampling
print("\nPréparation des données avec oversampling...")
train_files, test_files, train_labels, test_labels, class_names = prepare_data_with_oversampling(DATA_DIR)
len(train_files), len(test_files)
# Out:
# Préparation des données avec oversampling...
# /tmp/ipython-input-5-1811685672.py:27: UserWarning: Argument(s) 'alpha_affine' are not valid for transform ElasticTransform
#   A.ElasticTransform(alpha=1, sigma=50, alpha_affine=50, p=1),
# Balancing classes: 100%|██████████| 8/8 [03:24<00:00, 25.60s/it]
# (16000, 3427)

# %%
# Afficher les distributions des labels (listes d'entiers)
def plot_label_distribution(labels, title):
    """Plots the distribution of labels in a list."""
    label_counts = Counter(labels)
    # Sort by label index for consistent plotting
    sorted_labels = sorted(label_counts.keys())
    sorted_counts = [label_counts[label] for label in sorted_labels]

    plt.figure(figsize=(12, 6))
    plt.bar([str(label) for label in sorted_labels], sorted_counts) # Convert labels to string for x-axis
    plt.title(title)
    plt.xlabel('Class Index')
    plt.ylabel('Number of samples')
    plt.xticks(rotation=45)
    plt.show()

print("Distribution des labels d'entraînement après oversampling...")
plot_label_distribution(train_labels, 'Distribution des labels d\'entraînement (après oversampling)')
# Out:
# Distribution des labels d'entraînement après oversampling...

# %%
print("\nDistribution des labels de test...")
plot_label_distribution(test_labels, 'Distribution des labels de test')
# Out:
# Distribution des labels de test...

# %%
# 4. Création des datasets et dataloaders
print("\nCréation des datasets et dataloaders...")
train_dataset = CustomDataset(train_files, train_labels, transform=get_val_transform())
test_dataset = CustomDataset(test_files, test_labels, transform=get_val_transform())
# Out:
# Création des datasets et dataloaders...

# %%
train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE, shuffle=False)

# %%
import timm
# 5. Initialisation du modèle pré-entraîné deit_small
num_classes = len(class_names)
model = timm.create_model("deit_small_patch16_224", pretrained=True, num_classes=num_classes).to(device)
# Out:
# model.safetensors:   0%|          | 0.00/88.2M [00:00<?, ?B/s]

# %%
# 6. Configuration de l'entraînement
criterion = nn.CrossEntropyLoss()
optimizer = optim.AdamW(model.parameters(), lr=1e-4, betas=(0.9, 0.999), weight_decay=0.01)

# %%
# 7. Entraînement
print("\nDébut de l'entraînement...")
trained_model = train_model(
    model=model,
    train_loader=train_loader,
    val_loader=test_loader,
    criterion=criterion,
    optimizer=optimizer,
    num_epochs=NUM_EPOCHS,
    device=device
)

print("Entraînement terminé !")
# Out:
# Début de l'entraînement...
# Epoch 1/100
# Train Loss: 0.5938, Acc: 0.7845
# Val Loss: 0.5603, Acc: 0.8144
# Epoch 2/100
# Train Loss: 0.1938, Acc: 0.9374
# Val Loss: 0.4461, Acc: 0.8795
# Epoch 3/100
# Train Loss: 0.1327, Acc: 0.9561
# Val Loss: 0.2734, Acc: 0.9320
# Epoch 4/100
# Train Loss: 0.0975, Acc: 0.9683
# Val Loss: 0.3828, Acc: 0.8947
# Epoch 5/100
# Train Loss: 0.0882, Acc: 0.9724
# Val Loss: 0.3481, Acc: 0.9069
# Epoch 6/100
# Train Loss: 0.0695, Acc: 0.9791
# Val Loss: 0.2625, Acc: 0.9390
# Epoch 7/100
# Train Loss: 0.0649, Acc: 0.9790
# Val Loss: 0.3297, Acc: 0.9206
# Epoch 8/100
# Train Loss: 0.0542, Acc: 0.9828
# Val Loss: 0.5349, Acc: 0.8570
# Epoch 9/100
# Train Loss: 0.0559, Acc: 0.9819
# Val Loss: 0.2583, Acc: 0.9434
# Epoch 10/100
# Train Loss: 0.0605, Acc: 0.9814
# Val Loss: 0.7020, Acc: 0.8147
# Epoch 11/100
# Train Loss: 0.0403, Acc: 0.9876
# Val Loss: 0.2860, Acc: 0.9370
# Epoch 12/100
# Train Loss: 0.0445, Acc: 0.9870
# Val Loss: 0.2534, Acc: 0.9422
# Epoch 13/100
# Train Loss: 0.0373, Acc: 0.9884
# Val Loss: 0.3526, Acc: 0.9122
# Epoch 14/100
# Train Loss: 0.0408, Acc: 0.9878
# Val Loss: 0.2435, Acc: 0.9469
# Epoch 15/100
# Train Loss: 0.0378, Acc: 0.9875
# Val Loss: 0.2807, Acc: 0.9376
# Epoch 16/100
# Train Loss: 0.0342, Acc: 0.9889
# Val Loss: 0.3162, Acc: 0.9294
# Epoch 17/100
# Train Loss: 0.0354, Acc: 0.9888
# Val Loss: 0.2930, Acc: 0.9352
# Epoch 18/100
# Train Loss: 0.0213, Acc: 0.9936
# Val Loss: 0.3118, Acc: 0.9376
# Epoch 19/100
# Train Loss: 0.0353, Acc: 0.9893
# Val Loss: 0.4578, Acc: 0.8929
# Epoch 20/100
# Train Loss: 0.0290, Acc: 0.9909
# Val Loss: 0.4651, Acc: 0.8938
# Epoch 21/100
# Train Loss: 0.0230, Acc: 0.9934
# Val Loss: 0.3462, Acc: 0.9244
# Epoch 22/100
# Train Loss: 0.0221, Acc: 0.9933
# Val Loss: 0.4724, Acc: 0.8891
# Epoch 23/100
# Train Loss: 0.0323, Acc: 0.9894
# Val Loss: 0.2916, Acc: 0.9355
# Epoch 24/100
# Train Loss: 0.0234, Acc: 0.9928
# Val Loss: 0.5293, Acc: 0.8882
# Epoch 25/100
# Train Loss: 0.0207, Acc: 0.9938
# Val Loss: 0.3064, Acc: 0.9370
# Epoch 26/100
# Train Loss: 0.0215, Acc: 0.9933
# Val Loss: 0.3194, Acc: 0.9387
# Epoch 27/100
# Train Loss: 0.0242, Acc: 0.9923
# Val Loss: 0.4034, Acc: 0.9069
# Epoch 28/100
# Train Loss: 0.0238, Acc: 0.9932
# Val Loss: 0.3676, Acc: 0.9233
# Epoch 29/100
# Train Loss: 0.0206, Acc: 0.9942
# Val Loss: 0.2824, Acc: 0.9466
# Epoch 30/100
# Train Loss: 0.0194, Acc: 0.9942
# Val Loss: 0.2746, Acc: 0.9469
# Epoch 31/100
# Train Loss: 0.0223, Acc: 0.9928
# Val Loss: 0.2947, Acc: 0.9413
# Epoch 32/100
# Train Loss: 0.0221, Acc: 0.9936
# Val Loss: 0.2948, Acc: 0.9419
# Epoch 33/100
# Train Loss: 0.0161, Acc: 0.9957
# Val Loss: 0.3026, Acc: 0.9387
# Epoch 34/100
# Train Loss: 0.0243, Acc: 0.9931
# Val Loss: 0.2821, Acc: 0.9378
# Epoch 35/100
# Train Loss: 0.0136, Acc: 0.9954
# Val Loss: 0.2856, Acc: 0.9425
# Epoch 36/100
# Train Loss: 0.0226, Acc: 0.9929
# Val Loss: 0.4030, Acc: 0.9136
# Epoch 37/100
# Train Loss: 0.0144, Acc: 0.9953
# Val Loss: 0.3246, Acc: 0.9411
# Epoch 38/100
# Train Loss: 0.0074, Acc: 0.9982
# Val Loss: 0.3005, Acc: 0.9507
# Epoch 39/100
# Train Loss: 0.0219, Acc: 0.9932
# Val Loss: 0.3156, Acc: 0.9370
# Epoch 40/100
# Train Loss: 0.0203, Acc: 0.9936
# Val Loss: 0.2620, Acc: 0.9536
# Epoch 41/100
# Train Loss: 0.0061, Acc: 0.9987
# Val Loss: 0.2659, Acc: 0.9527
# Epoch 42/100
# Train Loss: 0.0015, Acc: 0.9998
# Val Loss: 0.3128, Acc: 0.9446
# Epoch 43/100
# Train Loss: 0.0328, Acc: 0.9893
# Val Loss: 0.3284, Acc: 0.9306
# Epoch 44/100
# Train Loss: 0.0166, Acc: 0.9945
# Val Loss: 0.3635, Acc: 0.9294
# Epoch 45/100
# Train Loss: 0.0090, Acc: 0.9969
# Val Loss: 0.2843, Acc: 0.9554
# Epoch 46/100
# Train Loss: 0.0154, Acc: 0.9956
# Val Loss: 0.3395, Acc: 0.9387
# Epoch 47/100
# Train Loss: 0.0203, Acc: 0.9938
# Val Loss: 0.2495, Acc: 0.9536
# Epoch 48/100
# Train Loss: 0.0128, Acc: 0.9963
# Val Loss: 0.3064, Acc: 0.9434
# Epoch 49/100
# Train Loss: 0.0185, Acc: 0.9942
# Val Loss: 0.3044, Acc: 0.9373
# Epoch 50/100
# Train Loss: 0.0123, Acc: 0.9964
# Val Loss: 0.3120, Acc: 0.9428
# Epoch 51/100
# Train Loss: 0.0134, Acc: 0.9961
# Val Loss: 0.3098, Acc: 0.9443
# Epoch 52/100
# Train Loss: 0.0139, Acc: 0.9960
# Val Loss: 0.3002, Acc: 0.9489
# Epoch 53/100
# Train Loss: 0.0143, Acc: 0.9955
# Val Loss: 0.3172, Acc: 0.9311
# Epoch 54/100
# Train Loss: 0.0195, Acc: 0.9942
# Val Loss: 0.3033, Acc: 0.9411
# Epoch 55/100
# Train Loss: 0.0084, Acc: 0.9974
# Val Loss: 0.2746, Acc: 0.9562
# Epoch 56/100
# Train Loss: 0.0057, Acc: 0.9984
# Val Loss: 0.2821, Acc: 0.9516
# Epoch 57/100
# Train Loss: 0.0196, Acc: 0.9948
# Val Loss: 0.3379, Acc: 0.9364
# Epoch 58/100
# Train Loss: 0.0129, Acc: 0.9961
# Val Loss: 0.3199, Acc: 0.9352
# Epoch 59/100
# Train Loss: 0.0112, Acc: 0.9970
# Val Loss: 0.2886, Acc: 0.9519
# Epoch 60/100
# Train Loss: 0.0160, Acc: 0.9951
# Val Loss: 0.2985, Acc: 0.9513
# Epoch 61/100
# Train Loss: 0.0106, Acc: 0.9966
# Val Loss: 0.3364, Acc: 0.9358
# Epoch 62/100
# Train Loss: 0.0080, Acc: 0.9972
# Val Loss: 0.6225, Acc: 0.8874
# Epoch 63/100
# Train Loss: 0.0155, Acc: 0.9957
# Val Loss: 0.3081, Acc: 0.9419
# Epoch 64/100
# Train Loss: 0.0082, Acc: 0.9979
# Val Loss: 0.3162, Acc: 0.9463
# Epoch 65/100
# Train Loss: 0.0121, Acc: 0.9967
# Val Loss: 0.3337, Acc: 0.9451
# Epoch 66/100
# Train Loss: 0.0129, Acc: 0.9964
# Val Loss: 0.2929, Acc: 0.9472
# Epoch 67/100
# Train Loss: 0.0114, Acc: 0.9969
# Val Loss: 0.3997, Acc: 0.9200
# Epoch 68/100
# Train Loss: 0.0089, Acc: 0.9976
# Val Loss: 0.4261, Acc: 0.9057
# Epoch 69/100
# Train Loss: 0.0029, Acc: 0.9996
# Val Loss: 0.3058, Acc: 0.9527
# Epoch 70/100
# Train Loss: 0.0028, Acc: 0.9993
# Val Loss: 0.3349, Acc: 0.9434
# Epoch 71/100
# Train Loss: 0.0274, Acc: 0.9919
# Val Loss: 0.3040, Acc: 0.9460
# Epoch 72/100
# Train Loss: 0.0145, Acc: 0.9964
# Val Loss: 0.3675, Acc: 0.9314
# Epoch 73/100
# Train Loss: 0.0119, Acc: 0.9967
# Val Loss: 0.3388, Acc: 0.9384
# Epoch 74/100
# Train Loss: 0.0022, Acc: 0.9994
# Val Loss: 0.3248, Acc: 0.9501
# Epoch 75/100
# Train Loss: 0.0027, Acc: 0.9993
# Val Loss: 0.5064, Acc: 0.8979
# Epoch 76/100
# Train Loss: 0.0239, Acc: 0.9926
# Val Loss: 0.2651, Acc: 0.9513
# Epoch 77/100
# Train Loss: 0.0061, Acc: 0.9982
# Val Loss: 0.3059, Acc: 0.9513
# Epoch 78/100
# Train Loss: 0.0068, Acc: 0.9977
# Val Loss: 0.2786, Acc: 0.9484
# Epoch 79/100
# Train Loss: 0.0161, Acc: 0.9954
# Val Loss: 0.2838, Acc: 0.9577
# Epoch 80/100
# Train Loss: 0.0070, Acc: 0.9982
# Val Loss: 0.2928, Acc: 0.9484
# Epoch 81/100
# Train Loss: 0.0065, Acc: 0.9983
# Val Loss: 0.3369, Acc: 0.9440
# Epoch 82/100
# Train Loss: 0.0134, Acc: 0.9959
# Val Loss: 0.2771, Acc: 0.9548
# Epoch 83/100
# Train Loss: 0.0049, Acc: 0.9990
# Val Loss: 0.2760, Acc: 0.9562
# Epoch 84/100
# Train Loss: 0.0135, Acc: 0.9958
# Val Loss: 0.2877, Acc: 0.9504
# Epoch 85/100
# Train Loss: 0.0098, Acc: 0.9974
# Val Loss: 0.2992, Acc: 0.9475
# Epoch 86/100
# Train Loss: 0.0129, Acc: 0.9964
# Val Loss: 0.2987, Acc: 0.9475
# Epoch 87/100
# Train Loss: 0.0117, Acc: 0.9967
# Val Loss: 0.2567, Acc: 0.9516
# Epoch 88/100
# Train Loss: 0.0030, Acc: 0.9994
# Val Loss: 0.2787, Acc: 0.9542
# Epoch 89/100
# Train Loss: 0.0012, Acc: 0.9997
# Val Loss: 0.3197, Acc: 0.9513
# Epoch 90/100
# Train Loss: 0.0007, Acc: 0.9999
# Val Loss: 0.3149, Acc: 0.9530
# Epoch 91/100
# Train Loss: 0.0001, Acc: 1.0000
# Val Loss: 0.3280, Acc: 0.9539
# Epoch 92/100
# Train Loss: 0.0000, Acc: 1.0000
# Val Loss: 0.3393, Acc: 0.9533
# Epoch 93/100
# Train Loss: 0.0000, Acc: 1.0000
# Val Loss: 0.3496, Acc: 0.9527
# Epoch 94/100
# Train Loss: 0.0000, Acc: 1.0000
# Val Loss: 0.3590, Acc: 0.9527
# Epoch 95/100
# Train Loss: 0.0000, Acc: 1.0000
# Val Loss: 0.3685, Acc: 0.9527
# Epoch 96/100
# Train Loss: 0.0000, Acc: 1.0000
# Val Loss: 0.3770, Acc: 0.9524
# Epoch 97/100
# Train Loss: 0.0000, Acc: 1.0000
# Val Loss: 0.3861, Acc: 0.9524
# Epoch 98/100
# Train Loss: 0.0000, Acc: 1.0000
# Val Loss: 0.3950, Acc: 0.9521
# Epoch 99/100
# Train Loss: 0.0000, Acc: 1.0000
# Val Loss: 0.4038, Acc: 0.9519
# Epoch 100/100
# Train Loss: 0.0000, Acc: 1.0000
# Val Loss: 0.4127, Acc: 0.9519
# Entraînement terminé !
